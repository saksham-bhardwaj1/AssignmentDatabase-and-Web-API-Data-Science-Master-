# %% [markdown]
# ### Q1. Explain GET and POST methods.

# %% [markdown]
# HTTP (Hypertext Transfer Protocol) is the protocol used for transmitting data over the internet. In HTTP, there are several methods available for transmitting data, but the two most commonly used methods are GET and POST.
#
# ##### GET Method:
# The GET method is used for retrieving data from a server. In a GET request, the data is sent as part of the URL, which is visible in the browser's address bar. GET requests are typically used for retrieving data from a server, such as viewing a web page or an image.
#
# ##### POST Method:
#
# The POST method is used for sending data to a server, such as submitting a form. In a POST request, the data is sent in the request body, which is not visible in the browser's address bar. POST requests are typically used for sending data to a server, such as submitting a form or creating a new record in a database.

# %% [markdown]
# ### Q2. Why is request used in Flask?

# %% [markdown]
# In Flask, a request is used to handle incoming HTTP requests from clients such as web browsers. The Flask request object provides a way to access the data that was sent in an HTTP request, including form data, query parameters, and headers.
#
# When a client sends an HTTP request to a Flask web application, the Flask framework generates a request object that contains all of the data from the request. This object is then passed to the view function that handles the request, allowing the function to access and process the data from the request.
#
# The request object in Flask provides many useful methods and attributes, such as:
#
# form attribute: This attribute provides access to the form data that was sent with the request. This can be useful for processing data from HTML forms.
#
#
# args attribute: This attribute provides access to the query parameters that were sent with the request.
#
#
# headers attribute: This attribute provides access to the headers that were sent with the request.
#
#
# Using the request object in Flask allows developers to build dynamic web applications that can handle user input and respond with customized output based on that input.

# %% [markdown]
# ### Q3. Why is redirect() used in Flask?

# %% [markdown]
# The redirect() function is used in Flask to redirect the user to a different page or URL. When a user accesses a web application, they make requests to the server, which returns a response containing HTML, CSS, and other resources. Sometimes, it is necessary to redirect the user to a different URL, for example, after they have submitted a form or logged in successfully.
#
# In Flask, the redirect() function can be used to redirect the user to a different URL. The function takes a URL as an argument and returns a response that redirects the user to that URL.

# %% [markdown]
# ### Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# Templates in Flask are files that contain HTML, CSS, and other content that are used to generate dynamic web pages. Templates are used in web applications to separate the presentation logic from the application logic, making it easier to manage and maintain the application. Flask uses the Jinja2 templating engine, which is a fast and flexible engine for rendering templates.
#
# In Flask, the render_template() function is used to render templates and return the result as a response. The function takes the name of the template file and any arguments that need to be passed to the template as keyword arguments.

# %% [markdown]
# ### Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
from flask import*

# %%
app=Flask(__name__)

# %%
@app.route('/',methods=['POST'])
def Welcome():
    result= "Hii"
    return jsonify(result)

if __name__=='__main__':
    app.run(host='0.0.0.0')
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.13:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/Mar/2023 23:48:55] "POST / HTTP/1.1" 200 -

# %% [markdown]
# ### OUTPUT:-
#
# ![image.png](attachment:image.png)
